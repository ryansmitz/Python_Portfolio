# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/ryansmitz/Instacart_Basket_Analysis_11_28_23'

# %%
df_ords_clean = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_ords_clean.csv'), index_col = False)

# %%
df_prods_clean = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_prods_clean.csv'), index_col = False)

# %%
df_orders_products_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'), index_col = False)

# %%
df_prods_clean.head(1)
# Out:
#    product_id                product_name  aisle_id  department_id  prices
# 0           1  Chocolate Sandwich Cookies        61             19     5.8

# %%
df_ords_clean.head(1)
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
#
#    days_since_prior_order
# 0                     NaN

# %%
df_orders_products_prior.head(1)
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1

# %%
df_prods_clean.shape
# Out:
# (49672, 5)

# %%
df_orders_products_prior.shape
# Out:
# (32434489, 4)

# %%
#df_orders_products_prior consistency checks
for col in df_orders_products_prior.columns.tolist():
  weird = (df_orders_products_prior[[col]].applymap(type) != df_orders_products_prior[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_orders_products_prior[weird]) > 0:
    print (col)
# Out:
# /var/folders/8s/hd59lm_10lz7xmm3phb5dc800000gn/T/ipykernel_6813/3023699902.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_orders_products_prior[[col]].applymap(type) != df_orders_products_prior[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/8s/hd59lm_10lz7xmm3phb5dc800000gn/T/ipykernel_6813/3023699902.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_orders_products_prior[[col]].applymap(type) != df_orders_products_prior[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/8s/hd59lm_10lz7xmm3phb5dc800000gn/T/ipykernel_6813/3023699902.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_orders_products_prior[[col]].applymap(type) != df_orders_products_prior[[col]].iloc[0].apply(type)).any(axis = 1)
# ...

# %%
df_orders_products_prior.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
df_orders_products_prior = df_orders_products_prior.drop_duplicates()

# %%
df_orders_products_prior.shape
# Out:
# (32434489, 4)

# %%
#1) merge the orders and products dataframes
df_merged_large = df_ords_clean.merge(df_orders_products_prior, on = 'order_id', indicator = True)

# %%
df_merged_large
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2539329        1             1                  2
# 2          2539329        1             1                  2
# 3          2539329        1             1                  2
# 4          2539329        1             1                  2
# ...            ...      ...           ...                ...
# 32434484   2977660   206209            13                  1
# 32434485   2977660   206209            13                  1
# 32434486   2977660   206209            13                  1
# 32434487   2977660   206209            13                  1
# 32434488   2977660   206209            13                  1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
# check shape of merged dataframe
df_merged_large.shape
# Out:
# (32434489, 10)

# %%
df_merged_large.drop('_merge', axis=1, inplace=True)

# %%
#2 export dataframe
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'df_orders_products_combined.pkl'))

# %%
#3 import dataframe (instead of having two seperate notebooks, this notebook is condensed into one)
df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_orders_products_combined.pkl'))

# %%
#view dataframe 
df_orders_products_combined
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2539329        1             1                  2
# 2          2539329        1             1                  2
# 3          2539329        1             1                  2
# 4          2539329        1             1                  2
# ...            ...      ...           ...                ...
# 32434484   2977660   206209            13                  1
# 32434485   2977660   206209            13                  1
# 32434486   2977660   206209            13                  1
# 32434487   2977660   206209            13                  1
# 32434488   2977660   206209            13                  1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
#4 check the shape
df_orders_products_combined.shape
# Out:
# (32434489, 9)

# %%
#5 merge dataframes
df_ords_prods_merge = df_merged_large.merge(df_prods_clean, on = 'product_id', how = 'inner', indicator = True)

# %%
#view merged dataframes
df_ords_prods_merge
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32404854   1320836   202557            17                  2
# 32404855     31526   202557            18                  5
# 32404856    758936   203436             1                  2
# 32404857   2745165   203436             2                  3
# 32404858   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %%
#check the shape
df_ords_prods_merge.shape
# Out:
# (32404859, 14)

# %%
# 6) confirm results of merge with merge flag
df_ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
#7 export dataframe
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'df_ords_prods_merge.pkl'))
