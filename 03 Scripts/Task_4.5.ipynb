# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/ryansmitz/Instacart_Basket_Analysis_11_28_23'

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_wrangled.csv'), index_col = False)

# %% [markdown]
# #checks on df_prods (#1 of the task) will be run after check on df_ords

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#checking if column was dropped
df_ords
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 0         2539329        1             1                  2
# 1         2398795        1             2                  3
# 2          473747        1             3                  3
# 3         2254736        1             4                  4
# 4          431534        1             5                  4
# ...           ...      ...           ...                ...
# 3421078   2266710   206209            10                  5
# 3421079   1854736   206209            11                  4
# 3421080    626363   206209            12                  1
# 3421081   2977660   206209            13                  1
# 3421082    272231   206209            14                  6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
#consistency check
df_ords.shape
# Out:
# (3421083, 6)

# %%
#2 Run the df.describe() function on your df_ords dataframe.
df_ords.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06       3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01       2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01       2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00       1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01       3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02       6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# ...

# %% [markdown]
# #5 Why does the days_since_prior_order column have less values than the other columns?
#
# Is 100 possibly too low of a value for the max of the order_number column

# %%
#3 check for mixed type data in the dataframe (there appear to be no mixed-type values)
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)
# Out:
# /var/folders/8s/hd59lm_10lz7xmm3phb5dc800000gn/T/ipykernel_73886/2521439000.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/8s/hd59lm_10lz7xmm3phb5dc800000gn/T/ipykernel_73886/2521439000.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/8s/hd59lm_10lz7xmm3phb5dc800000gn/T/ipykernel_73886/2521439000.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/8s/hd59lm_10lz7xmm3phb5dc800000gn/T/ipykernel_73886/2521439000.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %%
#5 run a check for missing values
df_ords.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# order_number                   0
# order_day_of_week              0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# #5 there are many missing values in the days_since_prior_order column.

# %%
df_ords_null = df_ords[df_ords['days_since_prior_order'].isnull()==True]

# %%
df_ords_null.head(20)
# Out:
#      order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0     2539329        1             1                  2                  8
# 11    2168274        2             1                  2                 11
# 26    1374495        3             1                  1                 14
# 39    3343014        4             1                  6                 11
# 45    2717275        5             1                  3                 12
# 50    2086598        6             1                  5                 18
# 54    2565571        7             1                  3                  9
# 75     600894        8             1                  6                  0
# 79     280530        9             1                  1                 17
# 83    1224907       10             1                  2                 14
# 89    2411567       11             1                  0                 11
# ...

# %%
df_ords_null['order_number'].describe()
# Out:
# count    206209.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0
# Name: order_number, dtype: float64

# %% [markdown]
# #5 and #6 Missing values occur because there is no prior order when the order number is 1. Simply eliminating these rows would lead to the loss of a lot of useful data. The values are missing for good reason. Using a flag column might for easier identification and analysis

# %%
df_ords
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 0         2539329        1             1                  2
# 1         2398795        1             2                  3
# 2          473747        1             3                  3
# 3         2254736        1             4                  4
# 4          431534        1             5                  4
# ...           ...      ...           ...                ...
# 3421078   2266710   206209            10                  5
# 3421079   1854736   206209            11                  4
# 3421080    626363   206209            12                  1
# 3421081   2977660   206209            13                  1
# 3421082    272231   206209            14                  6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
#7 check the orders dataframe for duplicates
df_ords_dups = df_ords[df_ords.duplicated()]

# %%
df_ords_dups
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_day_of_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
df_ords_clean = df_ords

# %% [markdown]
# #7There appear to be do duplicates in df_ords

# %% [markdown]
# #1 Now to run some checks on df_prods

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
#checking column was dropped
df_prods.head(1)
# Out:
#    product_id                product_name  aisle_id  department_id  prices
# 0           1  Chocolate Sandwich Cookies        61             19     5.8

# %%
#consistency check
df_prods.shape
# Out:
# (49693, 5)

# %%
#checking for null values in products dataframe
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
#investigating null values
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
#visualizing null values within the context of the full dataframe
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
#taking out the rows with null values
df_prods = df_prods[df_prods['product_name'].isnull() == False]

# %%
#making sure the 16 rows will null values were removed and this is the case
df_prods.shape
# Out:
# (49677, 5)

# %%
#check the prods dataframe for duplicates
df_prods_dups = df_prods[df_prods.duplicated()]

# %%
df_prods_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
#dropping the duplicate values from the dataframe
df_prods_clean = df_prods.drop_duplicates()

# %%
#checking that the duplicate values were dropped
df_prods_clean.shape
# Out:
# (49672, 5)

# %%
df_prods_clean.to_csv(os.path.join(path, '02 Data','Prepared Data', 'df_prods_clean.csv'), index = False)

# %%
df_ords_clean.to_csv(os.path.join(path, '02 Data','Prepared Data', 'df_ords_clean.csv'), index = False)
