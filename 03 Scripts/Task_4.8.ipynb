# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/ryansmitz/Instacart_Basket_Analysis_11_28_23'

# %%
#1 import dataframe
df_ords_prods_merge_2 = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_ords_prods_merge_2.pkl'))

# %%
#check the dataframe visually
df_ords_prods_merge_2
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32404854   1320836   202557            17                  2
# 32404855     31526   202557            18                  5
# 32404856    758936   203436             1                  2
# 32404857   2745165   203436             2                  3
# 32404858   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %%
print(df_ords_prods_merge_2.dtypes)
# Out:
# order_id                      int64
# user_id                       int64
# order_number                  int64
# order_day_of_week             int64
# order_hour_of_day             int64
# days_since_prior_order      float64
# product_id                    int64
# add_to_cart_order             int64
# reordered                     int64
# product_name                 object
# aisle_id                      int64
# department_id                 int64
# prices                      float64
# _merge                     category
# price_range_loc              object
# order_day_of_week_label      object
# busiest_days                 object
# busiest_period_of_day        object
# dtype: object

# %%
#find the aggregated mean for entire dataframe grouped by department id
df_ords_prods_merge_2.groupby('department_id').agg({
    'order_number': 'mean',
    'order_day_of_week': 'mean',
    'order_hour_of_day': 'mean',
    'days_since_prior_order': 'mean',
    'add_to_cart_order': 'mean',
    'reordered': 'mean',
    'prices': 'mean'
})
# Out:
#                order_number  order_day_of_week  order_hour_of_day  \
# department_id
# 1                 15.457838           2.790508          13.681669
# 2                 17.277920           2.851368          13.498939
# 3                 17.170395           2.743055          13.398569
# 4                 17.811403           2.683672          13.424949
# 5                 15.215751           3.163153          13.594264
# 6                 16.439806           2.691937          13.518913
# 7                 17.225802           2.807199          13.314115
# 8                 15.340650           2.934893          13.578544
# 9                 15.895474           2.690505          13.546041
# 10                20.197148           2.759061          13.458537
# 11                16.170638           2.816660          13.486800
# 12                15.887671           2.718082          13.468507
# 13                16.583536           2.810497          13.458808
# ...

# %% [markdown]
# #3 Each figure in the table represents different aspects of the data. The order_number column allows us to compare order numbers between departments. The price column gives an idea of the average price of the purchased products in each department. This can provide information about price differences between departments or possibly buying habits. The hour_of_day column shows the average time of day that items are purchased, again by department. The hour_of_day column shows less variation than say, the price column. All departments show that items are purchased on average sometime between 1pm and 2pm.

# %%
#4 create a max order column
df_ords_prods_merge_2['max_order'] = df_ords_prods_merge_2.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/8s/hd59lm_10lz7xmm3phb5dc800000gn/T/ipykernel_4122/3937422271.py:2: FutureWarning: The provided callable <function amax at 0x10e4d14e0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge_2['max_order'] = df_ords_prods_merge_2.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#eliminate max rows view
pd.options.display.max_rows = None

# %%
#check the dataframe visually
df_ords_prods_merge_2.head(100)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# ...

# %%
#4 create a loyalty flag column using the max order column
df_ords_prods_merge_2.loc[df_ords_prods_merge_2['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# Out:
# /var/folders/8s/hd59lm_10lz7xmm3phb5dc800000gn/T/ipykernel_4122/3519078072.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Loyal customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_ords_prods_merge_2.loc[df_ords_prods_merge_2['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merge_2.loc[(df_ords_prods_merge_2['max_order'] <= 40) & (df_ords_prods_merge_2['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merge_2.loc[df_ords_prods_merge_2['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#visual check that the new column was created succesfully
df_ords_prods_merge_2.head(30)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# ...

# %%
#check the value counts of the new loyalty flag
df_ords_prods_merge_2['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
#5 check the basic statistics of the product prices for each loyalty category
df_ords_prods_merge_2.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.373859  1.0  99999.0
# New customer      13.285336  1.0  99999.0
# Regular customer  12.485148  1.0  99999.0

# %%
#6 create a spending flag for each user based on the average price across all their orders
df_ords_prods_merge_2['average_purchase'] = df_ords_prods_merge_2.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# /var/folders/8s/hd59lm_10lz7xmm3phb5dc800000gn/T/ipykernel_4122/1625380332.py:2: FutureWarning: The provided callable <function mean at 0x10e4d2200> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_ords_prods_merge_2['average_purchase'] = df_ords_prods_merge_2.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# check the average_purchase column visually
df_ords_prods_merge_2.head(25)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# ...

# %%
#create a purchase flag column with two categories: high spender and low spender
df_ords_prods_merge_2.loc[df_ords_prods_merge_2['average_purchase'] < 10, 'purchase_flag'] = 'Low Spender'

# %%
df_ords_prods_merge_2.loc[df_ords_prods_merge_2['average_purchase'] >= 10, 'purchase_flag'] = 'High Spender'

# %%
#visually check that the new column was created
df_ords_prods_merge_2.head(10)
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
# 5   3367565        1             6                  2                  7
# 6    550135        1             7                  1                  9
# 7   3108588        1             8                  1                 14
# 8   2295261        1             9                  1                 16
# 9   2550362        1            10                  4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# ...

# %%
#7 create a column that shows a user's median order frequency
df_ords_prods_merge_2['median_order_frequency'] = df_ords_prods_merge_2.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# /var/folders/8s/hd59lm_10lz7xmm3phb5dc800000gn/T/ipykernel_4122/1193648839.py:2: FutureWarning: The provided callable <function median at 0x10e724540> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df_ords_prods_merge_2['median_order_frequency'] = df_ords_prods_merge_2.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
#visually check the new column
df_ords_prods_merge_2.head(25)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# ...

# %%
#7 create a median order frequency flag column with three categories
df_ords_prods_merge_2.loc[df_ords_prods_merge_2['median_order_frequency'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
# Out:
# /var/folders/8s/hd59lm_10lz7xmm3phb5dc800000gn/T/ipykernel_4122/455290917.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Non-frequent customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_ords_prods_merge_2.loc[df_ords_prods_merge_2['median_order_frequency'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
df_ords_prods_merge_2.loc[(df_ords_prods_merge_2['median_order_frequency'] <= 20) & (df_ords_prods_merge_2['median_order_frequency'] > 10), 'order_frequency_flag'] = 'Regular customer'

# %%
df_ords_prods_merge_2.loc[df_ords_prods_merge_2['median_order_frequency'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
df_ords_prods_merge_2.head(25)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# ...

# %%
df_ords_prods_merge_2.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'df_ords_prods_merged_3.pkl'))
